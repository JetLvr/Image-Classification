# %% [markdown]
# __&nbsp;Image classification is a common task in machine learning, where an algorithm is trained to classify images into one or more predefined categories. TensorFlow and Keras are popular tools for building and training deep learning models for image classification.__

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
# Load the dataset
train_ds = keras.preprocessing.image_dataset_from_directory(
    "../local_folder/for_classification",
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224, 224),
    batch_size=32,
)
val_ds = keras.preprocessing.image_dataset_from_directory(
    "../local_folder/for_classification",
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(224, 224),
    batch_size=32,
)
# Out:
# Found 316 files belonging to 2 classes.
# Using 253 files for training.
# Found 316 files belonging to 2 classes.
# Using 63 files for validation.

# %%
# Create the model
num_classes = 2
model = keras.Sequential([
    layers.experimental.preprocessing.Rescaling(1./255),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# Train the model
model.fit(train_ds, validation_data=val_ds, epochs=10)
# Out:
# Epoch 1/10
# /home/brunovalle/miniconda3/envs/tf-gpu-cuda8/lib/python3.6/site-packages/keras/backend.py:4907: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 8/8 [==============================] - 10s 1s/step - loss: 0.9298 - accuracy: 0.4704 - val_loss: 0.6900 - val_accuracy: 0.5873
# Epoch 2/10
# 8/8 [==============================] - 10s 1s/step - loss: 0.6878 - accuracy: 0.5415 - val_loss: 0.6881 - val_accuracy: 0.5079
# Epoch 3/10
# 8/8 [==============================] - 10s 1s/step - loss: 0.6770 - accuracy: 0.5850 - val_loss: 0.7367 - val_accuracy: 0.4286
# Epoch 4/10
# 8/8 [==============================] - 10s 1s/step - loss: 0.6337 - accuracy: 0.6838 - val_loss: 0.7150 - val_accuracy: 0.4603
# Epoch 5/10
# 8/8 [==============================] - 11s 1s/step - loss: 0.6150 - accuracy: 0.6206 - val_loss: 0.6995 - val_accuracy: 0.6190
# Epoch 6/10
# 8/8 [==============================] - 10s 1s/step - loss: 0.5181 - accuracy: 0.8261 - val_loss: 0.7750 - val_accuracy: 0.5873
# Epoch 7/10
# 8/8 [==============================] - 10s 1s/step - loss: 0.4206 - accuracy: 0.8340 - val_loss: 0.7914 - val_accuracy: 0.6349
# Epoch 8/10
# 8/8 [==============================] - 10s 1s/step - loss: 0.3069 - accuracy: 0.8933 - val_loss: 0.6217 - val_accuracy: 0.6667
# Epoch 9/10
# 8/8 [==============================] - 10s 1s/step - loss: 0.2146 - accuracy: 0.9209 - val_loss: 0.3770 - val_accuracy: 0.8095
# Epoch 10/10
# 8/8 [==============================] - 10s 1s/step - loss: 0.1256 - accuracy: 0.9644 - val_loss: 0.4379 - val_accuracy: 0.7778

# %%
# Evaluate the model
image_paths = os.listdir("../local_folder/hold_out")

for i in image_paths:
    img = keras.preprocessing.image.load_img(
        "../local_folder/hold_out/"+i, target_size=(224, 224)
    )
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create batch axis
    predictions = model.predict(img_array)
    score = np.argmax(predictions)
    
    if score == 0:
        pred = "Airbus"
    else:
        pred = "Boeing"
    
    print(f"Actual: {i}\nPredicted as: {pred}\n")
    print("Probabilities for:\n   Airbus:",
          f"{predictions[0][0]:.0%}",
          f"\n   Boeing:  {predictions[0][1]:.0%}")
    print("-"*40)
    print("\n")
# Out:
# Actual: AirbusA320-251N(14).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 72%
#    Boeing:  28%
# ----------------------------------------
#
#
# Actual: Boeing737-8AS(4).jpg
# Predicted as: Boeing
#
# Probabilities for:
#    Airbus: 1%
#    Boeing:  99%
# ----------------------------------------
#
#
# Actual: AirbusA320-214(56).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 100%
#    Boeing:  0%
# ----------------------------------------
#
#
# Actual: Boeing737-2T4-Adv.jpg
# Predicted as: Boeing
#
# Probabilities for:
#    Airbus: 29%
#    Boeing:  71%
# ----------------------------------------
#
#
# Actual: AirbusA320-214(36).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 54%
#    Boeing:  46%
# ----------------------------------------
#
#
# Actual: Boeing737-4M0(SF).jpg
# Predicted as: Boeing
#
# Probabilities for:
#    Airbus: 3%
#    Boeing:  97%
# ----------------------------------------
#
#
# Actual: Boeing737-800(3).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 73%
#    Boeing:  27%
# ----------------------------------------
#
#
# Actual: AirbusA320-214(34).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 72%
#    Boeing:  28%
# ----------------------------------------
#
#
# Actual: AirbusA320-232(22).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 81%
#    Boeing:  19%
# ----------------------------------------
#
#
# Actual: AirbusA320-232(38).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 100%
#    Boeing:  0%
# ----------------------------------------
#
#
# Actual: AirbusA320-271N(4).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 99%
#    Boeing:  1%
# ----------------------------------------
#
#
# Actual: Boeing737-808(WL).jpg
# Predicted as: Boeing
#
# Probabilities for:
#    Airbus: 2%
#    Boeing:  98%
# ----------------------------------------
#
#
# Actual: Boeing737-84P.jpg
# Predicted as: Boeing
#
# Probabilities for:
#    Airbus: 30%
#    Boeing:  70%
# ----------------------------------------
#
#
# Actual: AirbusA320-271N(3).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 99%
#    Boeing:  1%
# ----------------------------------------
#
#
# Actual: AirbusA320-214(10).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 99%
#    Boeing:  1%
# ----------------------------------------
#
#
# Actual: Boeing737-8MAX(22).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 98%
#    Boeing:  2%
# ----------------------------------------
#
#
# Actual: Boeing737MAX8-200.jpg
# Predicted as: Boeing
#
# Probabilities for:
#    Airbus: 0%
#    Boeing:  100%
# ----------------------------------------
#
#
# Actual: AirbusA320-232(14).jpg
# Predicted as: Airbus
#
# Probabilities for:
#    Airbus: 100%
#    Boeing:  0%
# ----------------------------------------
#
#
# Actual: Boeing737-8FE(WL).jpg
# Predicted as: Boeing
#
# Probabilities for:
#    Airbus: 34%
#    Boeing:  66%
# ----------------------------------------
#
#
# Actual: Boeing737-75TBBJ(2).jpg
# Predicted as: Boeing
#
# Probabilities for:
#    Airbus: 5%
#    Boeing:  95%
# ----------------------------------------
